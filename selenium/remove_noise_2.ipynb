# %%
from PIL import Image 
img = Image.open('result.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=122x46 at 0x94434B0>

# %%
import cv2

img = cv2.imread('result.jpg')

# %%
dst = cv2.fastNlMeansDenoisingColored(img, None, 35, 35, 7, 30)

# %%
import matplotlib.pyplot as plt

plt.subplot(121)
plt.imshow(img)
plt.subplot(122)
plt.imshow(dst)
